# %%
import matplotlib.pyplot as plt
import pandas as pd

x = ['0-10', '10-20', '20-30', '30-40', 'ALL']

# %% [markdown]
# ## results of all experiments are listed here

# %%
ComCNN_lstm_lstm_beam3_bleu3 = [0.3172, 0.2139, 0.2096, 0.1922, 0.2849]
ComCNN_lstm_lstm_beam3_bleu4 = [0.2965, 0.2045, 0.1973, 0.1800, 0.2739]
ComCNN_lstm_lstm_beam3_cider = [0.3368, 0.2381, 0.2301, 0.2090, 0.3055]
ComCNN_lstm_lstm_beam3_rouge = [0.4390, 0.3579, 0.3365, 0.3227, 0.4120]

ComCNN_cnnlstm_lstm_beam3_bleu3 = [0.3048, 0.2215, 0.2170, 0.2022, 0.2787]
ComCNN_cnnlstm_lstm_beam3_bleu4 = [0.2929, 0.2123, 0.2085, 0.1963, 0.2678]
ComCNN_cnnlstm_lstm_beam3_cider = [0.3230, 0.2419, 0.2346, 0.2215, 0.2973]
ComCNN_cnnlstm_lstm_beam3_rouge = [0.4255, 0.3502, 0.3271, 0.3148, 0.4001]

ComCNN_bilstm_lstm_beam3_bleu3 = [0.3151, 0.2208, 0.2160, 0.1753, 0.2850]
ComCNN_bilstm_lstm_beam3_bleu4 = [0.3059, 0.2103, 0.2061, 0.1658, 0.2754]
ComCNN_bilstm_lstm_beam3_cider = [0.3341, 0.2415, 0.2356, 0.1955, 0.3043]
ComCNN_bilstm_lstm_beam3_rouge = [0.4343, 0.3577, 0.3334, 0.2980, 0.4078]

ComCNN_cnnbilstm_lstm_beam3_bleu3 = [0.3196, 0.2336, 0.2373, 0.2052, 0.2930]
ComCNN_cnnbilstm_lstm_beam3_bleu4 = [0.3105, 0.2238, 0.2282, 0.1964, 0.2837]
ComCNN_cnnbilstm_lstm_beam3_cider = [0.3366, 0.2525, 0.2511, 0.2245, 0.3102]
ComCNN_cnnbilstm_lstm_beam3_rouge = [0.4322, 0.3601, 0.3413, 0.3256, 0.4081]

ComCNN_cnnbilstm_lstm_no_idsplit_beam3_bleu3 = [0.3071, 0.2516, 0.2503, 0.2296, 0.2896]
ComCNN_cnnbilstm_lstm_no_idsplit_beam3_bleu4 = [0.2965, 0.2423, 0.2414, 0.2203, 0.2794]
ComCNN_cnnbilstm_lstm_no_idsplit_beam3_cider = [0.3184, 0.2624, 0.2588, 0.2410, 0.3006]
ComCNN_cnnbilstm_lstm_no_idsplit_beam3_rouge = [0.4047, 0.3541, 0.3409, 0.3194, 0.3876]

CODENN_beam3_bleu3 = [0.2896, 0.1994, 0.2065, 0.1906, 0.2624]
CODENN_beam3_bleu4 = [0.2835, 0.1919, 0.2000, 0.1844, 0.2560]
CODENN_beam3_cider = [0.3007, 0.2169, 0.2232, 0.2002, 0.2752]
CODENN_beam3_rouge = [0.3715, 0.3074, 0.2976, 0.2718, 0.3504]

DeepCom_beam3_bleu3 = [0.2812, 0.1821, 0.1969, 0.1482, 0.2505]
DeepCom_beam3_bleu4 = [0.2731, 0.1743, 0.1883, 0.1446, 0.2427]
DeepCom_beam3_cider = [0.2924, 0.2005, 0.2136, 0.1615, 0.2636]
DeepCom_beam3_rouge = [0.3714, 0.2900, 0.2906, 0.2350, 0.3444]

HybridDeepCom_beam3_bleu3 = [0.2722, 0.1737, 0.1257, 0.0699, 0.2407]
HybridDeepCom_beam3_bleu4 = [0.2628, 0.1644, 0.1179, 0.0612, 0.2314]
HybridDeepCom_beam3_cider = [0.2981, 0.2025, 0.1606, 0.1043, 0.2679]
HybridDeepCom_beam3_rouge = [0.3926, 0.3076, 0.2636, 0.2049, 0.3650]

IR_bleu3 = [0.0019, 0.0034, 0.0055, 0.0056, 0.0033]
IR_bleu4 = [0.0014, 0.0031, 0.0052, 0.0052, 0.0029]
IR_cider = [0.0149, 0.0264, 0.0269, 0.0253, 0.0188]
IR_rouge = [0.0448, 0.0777, 0.0670, 0.0782, 0.0530]

ComCNN_cnnbilstm_lstm_meam_pooling_beam3_bleu3 = [0.2975, 0.2094, 0.1863, 0.1765, 0.2718]
ComCNN_cnnbilstm_lstm_meam_pooling_beam3_bleu4 = [0.2853, 0.1974, 0.1788, 0.1689, 0.2600]
ComCNN_cnnbilstm_lstm_meam_pooling_beam3_cider = [0.3192, 0.2335, 0.2146, 0.2053, 0.2945]
ComCNN_cnnbilstm_lstm_meam_pooling_beam3_rouge = [0.4212, 0.3370, 0.3093, 0.2956, 0.3961]

# %%
fig, axs = plt.subplots(3)
#axs[0].plot(x, ComCNN_lstm_lstm_beam3_bleu3, 'o-', label="LSTM")
#axs[0].plot(x, ComCNN_cnnlstm_lstm_beam3_bleu3, '^-', label="CNN+LSTM")
#axs[0].plot(x, ComCNN_cnnbilstm_lstm_beam3_bleu3, 's-', label="CNN+BiLSTM")
#axs[0].plot(x, IR_bleu3, 's-', label="IR")

#axs[0].plot(x, ComCNN_cnnbilstm_lstm_beam3_bleu3, 'o-', label="Max-Pooling")
#axs[0].plot(x, ComCNN_cnnbilstm_lstm_meam_pooling_beam3_bleu3, '^--', label="Mean-Pooling")

axs[0].plot(x, ComCNN_cnnbilstm_lstm_beam3_bleu3, 'o-', label="ComCNN")
axs[0].plot(x, CODENN_beam3_bleu3, '^--', label="CODE-NN")
axs[0].plot(x, DeepCom_beam3_bleu3, '-.', label="DeepCom")
axs[0].plot(x, HybridDeepCom_beam3_bleu3, ':', label="Hybrid-DeepCom")
axs[0].legend(loc = 3)
axs[0].set_xlabel('LOC level')
axs[0].set_ylabel('BLEU3'+' (beam search k=3)')


#axs[1].plot(x, ComCNN_lstm_lstm_beam3_cider, 'o-', label="LSTM")
#axs[1].plot(x, ComCNN_cnnlstm_lstm_beam3_cider, '^-', label="CNN+LSTM")
#axs[1].plot(x, ComCNN_cnnbilstm_lstm_beam3_cider, 's-', label="CNN+BiLSTM")
#axs[1].plot(x, IR_cider, 's-', label="IR")

#axs[1].plot(x, ComCNN_cnnbilstm_lstm_beam3_cider, 'o-', label="Max-Pooling")
#axs[1].plot(x, ComCNN_cnnbilstm_lstm_meam_pooling_beam3_cider, '^--', label="Mean-Pooling")

axs[1].plot(x, ComCNN_cnnbilstm_lstm_beam3_cider, 'o-', label="ComCNN")
axs[1].plot(x, CODENN_beam3_cider, '^--', label="CODE-NN")
axs[1].plot(x, DeepCom_beam3_cider, '-.', label="DeepCom")
axs[1].plot(x, HybridDeepCom_beam3_cider, ':', label="Hybrid-DeepCom")
axs[1].legend(loc = 3)
axs[1].set_xlabel('LOC level')
axs[1].set_ylabel('CIDEr'+' (beam search k=3)')

#axs[2].plot(x, ComCNN_lstm_lstm_beam3_rouge, 'o-', label="LSTM")
#axs[2].plot(x, ComCNN_cnnlstm_lstm_beam3_rouge, '^-', label="CNN+LSTM")
#axs[2].plot(x, ComCNN_cnnbilstm_lstm_beam3_rouge, 's-', label="CNN+BiLSTM")
#axs[2].plot(x, IR_rouge, 's-', label="IR")

#axs[2].plot(x, ComCNN_cnnbilstm_lstm_beam3_rouge, 'o-', label="Max-Pooling")
#axs[2].plot(x, ComCNN_cnnbilstm_lstm_meam_pooling_beam3_rouge, '^--', label="Mean-Pooling")

axs[2].plot(x, ComCNN_cnnbilstm_lstm_beam3_rouge, 'o-', label="ComCNN")
axs[2].plot(x, CODENN_beam3_rouge, '^--', label="CODE-NN")
axs[2].plot(x, DeepCom_beam3_rouge, '-.', label="DeepCom")
axs[2].plot(x, HybridDeepCom_beam3_rouge, ':', label="Hybrid-DeepCom")
axs[2].legend(loc = 3)
axs[2].set_xlabel('LOC level')
axs[2].set_ylabel('ROUGE-L'+' (beam search k=3)')

fig.set_size_inches(12,14)
fig = plt.gcf()
plt.show()

# %%
save_path = "../result_img/state_of_art.png"
fig.savefig(save_path, dpi=200, bbox_inches='tight')
